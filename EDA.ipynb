# %%
import pandas as pd
import plotly.express as px

car_data = pd.read_csv('vehicles.csv')
hist = px.histogram(car_data, x="odometer")
hist.show()

# %%
scat = px.scatter(car_data, x="odometer")
scat.show()
